# %%
import numpy as np
import statistics 
from numpy import linalg as LA
a=np.array([[1,1],[2,2],[3,1],[4,1]])
statistics.mean(a[:,1])
b=a.transpose()
x=np.matmul(a,b)
print(x)
w, v = LA.eig(x)
print(v)
print(w)
v=([0.116,0.9933])
x=np.matmul(b,v)
x
# Out:
# [[0.75 0.5 ]
#  [0.5  5.  ]]
# [[-0.99333206 -0.1152884 ]
#  [ 0.1152884  -0.99333206]]
# [0.69196885 5.05803115]
# array([-1.46095, -0.58365,  0.52565,  1.51895])

# %%
import numpy as np
import statistics 
from numpy import linalg as LA
a=np.array([[1,1],[2,2],[3,1],[4,1]])
a[:,1]
statistics.mean(a[:,1])
# Out:
# 1

# %%
import numpy as np
import statistics 
from numpy import linalg as LA
a=np.array([[1,1],[2,2],[3,1],[4,1]])
column(a, 1)
statistics.mean(a[:,1])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-b170d16edf24> in <module>
#       3 from numpy import linalg as LA
#       4 a=np.array([[1,1],[2,2],[3,1],[4,1]])
# ----> 5 column(a, 1)
#       6 statistics.mean(a[:,1])
#
# NameError: name 'column' is not defined

# %%
import numpy as np
import statistics 
from numpy import linalg as LA
a=np.array([[1,1],[2,2],[3,1],[4,1]])
statistics.mean(a[:,1])
b=a.transpose()
x=np.matmul(a,b)
print(x)
w, v = LA.eig(x)
print(v)
print(w)
v=([0.116,0.9933])
x=np.matmul(b,v)
x
# Out:
# [[ 2  4  4  5]
#  [ 4  8  8 10]
#  [ 4  8 10 13]
#  [ 5 10 13 17]]
# [[-0.22142827+0.0000000e+00j  0.38462867+0.0000000e+00j
#   -0.11586665+3.9947510e-01j -0.11586665-3.9947510e-01j]
#  [-0.44285654+0.0000000e+00j  0.76925735+0.0000000e+00j
#   -0.06476898-1.9973755e-01j -0.06476898+1.9973755e-01j]
#  [-0.53182777+0.0000000e+00j -0.18799212+0.0000000e+00j
#    0.73621381+0.0000000e+00j  0.73621381-0.0000000e+00j]
#  [-0.68702753+0.0000000e+00j -0.47430252+0.0000000e+00j
#   -0.49080921+1.4444107e-16j -0.49080921-1.4444107e-16j]]
# [3.51207701e+01+0.00000000e+00j 1.87922986e+00+0.00000000e+00j
#  2.02824674e-16+3.19437206e-16j 2.02824674e-16-3.19437206e-16j]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-5-1db5a7472ca1> in <module>
#      11 print(w)
#      12 v=([0.116,0.9933])
# ---> 13 x=np.matmul(b,v)
#      14 x
#      15
#
# ...

# %%
import numpy as np
import statistics 
from numpy import linalg as LA
a=np.array([[0.5773,-1.732,0.5773,0.5773],[-1.34,-0.447,0.447,1.34]])
b=a.transpose()
x=np.matmul(a,b)
print(x)
w, v = LA.eig(x)
print(v)
print(w)
# Out:
# [[3.99964987 1.0322571 ]
#  [1.0322571  3.990818  ]]
# [[ 0.70861763 -0.70559269]
#  [ 0.70559269  0.70861763]]
# [5.02750048 2.96296739]

# %%
z=[-0.543, -1.53,0.7207,1.352] 
import matplotlib.pyplot as plt
plt.plot(z,[0,0,0,0],'ro',label='compressed data')
plt.plot([1,2,3,4],[1,2,1,1],'g^',label='original dataset')
plt.plot([0,0.7071],[0,-0.7071],label='eigen vector')
plt.ylabel('y axis')
plt.ylabel('x axis')
plt.title("part A")
plt.legend(loc=2)
plt.show()

# %%
z=[-0.8838,-0.8838,0.5303,1.237] 
import matplotlib.pyplot as plt
fig=plt.figure()
fig.show()
ax=fig.add_subplot(111)

ax.plot(z,[0,0,0,0],'ro',label='compressed data')
ax.plot([-1,-2,-1,-1],[1,2,3,4],'g^',label='original dataset')
ax.plot([0,0.7071],[0,0.7071],label='eigen vector')
plt.ylabel('y axis')
plt.ylabel('x axis')
plt.title("part B")
plt.legend(loc=2)

plt.show()

# %%
x=np.arange(6)
fig=plt.figure()
fig.show()
ax=fig.add_subplot(111)

ax.plot(x,x,c='b',marker="^",ls='--',label='GNE',fillstyle='none')
ax.plot(x,x+1,c='g',marker=(8,2,0),ls='--',label='MMR')
ax.plot(x,(x+1)**2,c='k',ls='-',label='Rand')
ax.plot(x,(x-1)**2,c='r',marker="v",ls='-',label='GMC')
ax.plot(x,x**2-1,c='m',marker="o",ls='--',label='BSwap',fillstyle='none')
ax.plot(x,x-1,c='k',marker="+",ls=':',label='MSD')

plt.legend(loc=2)
plt.draw()

# %%
z=[-0.8838,-0.8838,0.5303,1.237] 
import matplotlib.pyplot as plt
fig=plt.figure()
fig.show()
ax=fig.add_subplot(111)

ax.plot(z,[0,0,0,0],'ro',label='compressed data')
ax.plot([-1,-2,-1,-1],[1,2,3,4],'g^',label='original dataset')
ax.plot([0,0.7071],[0,0.7071],label='eigen vector')
plt.ylabel('y axis')
plt.ylabel('x axis')
plt.legend(loc=2)

plt.show()
